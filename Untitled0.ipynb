# %% [markdown]
# <a href="https://colab.research.google.com/github/vidyamp/git-journey/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=2
b=3
c=a+b
print(c)
# Out:
# 5

# %%
if 5 >2:

    print("five is greater than teo!")
# Out:
# five is greater than teo!

# %%
a=5
b='hello'
print(b)
# Out:
# hello

# %%
x="awesome"
def myfun():
  print("python is" , x)
myfun()

#in python variables can be declared globally,be utilized within function
# Out:
# python is awesome

# %%
x="awesome"
def myfun():
  x="fantastic"
  print("python is " + x)
myfun()

print("python is " + x)

#if you create a variable with the same name inside a function, this variable will be a local, and can only be used inside the function. The global variable with the same name will remain as it was, global and with the original value.
# Out:
# python is fantastic
# python is awesome
